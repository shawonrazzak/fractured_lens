# %%
# %reset -f
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from drone_model import DroneSimulator
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Set the trajectory

# %%
# Time
dt = 0.1
fs = 1 / dt
tsim = np.arange(0, 5.0 + dt/2, step=dt)

# %%
# Ambient wind speed & direction
w = 2.0 * np.ones_like(tsim)  # ambient wind speed magnitude
zeta = np.pi * np.ones_like(tsim)  # ambient wind direction

# Altitude
z = 2.0 * np.ones_like(tsim)  # altitude

# Velocity magnitude and direction
g = 1.0 * np.ones_like(tsim)  # ground speed magnitude
psi_global = (np.pi/4) * np.ones_like(tsim)  # global course direction
psi_global[30:] = psi_global[30] + np.pi/2

# Global frame x-y velocities
v_x_global = g * np.cos(psi_global)
v_y_global = g * np.sin(psi_global)

# Heading
psi = (np.pi/4) * np.ones_like(tsim)
psi[30:] = psi[30] + np.pi/2

# Body-level frame x-y velocities
v_x = v_x_global * np.cos(psi) + v_y_global * np.sin(psi)
v_y = -v_x_global * np.sin(psi) + v_y_global * np.cos(psi)

# %% [markdown]
# # Simulate trajectory

# %%
mpc_horizon = 10
mpc_control_penalty = 1e-2

# %%
# Create simulator
simulator = DroneSimulator(dt=dt, mpc_horizon=mpc_horizon, r_u=mpc_control_penalty)

# Change parameters
print(simulator.params.__dict__.keys())
simulator.params.Mm = 2.0  # example change the mass
# Out:
# dict_keys(['g', 'm', 'M', 'Mm', 'L', 'R', 'I_x', 'I_y', 'I_z', 'b', 'd', 'C'])

# %%
# Update the setpoints
simulator.update_setpoint(v_x=v_x, v_y=v_y, psi=psi, z=z, w=w, zeta=zeta)

# Run
t_sim, x_sim, u_sim, y_sim = simulator.simulate(x0=None, mpc=True, return_full_output=True)
sim_data = pd.DataFrame(y_sim)
sim_data.insert(0, 'time', t_sim)
print('Done.')
# Out:
# Done.

# %%
sim_data
# Out:
#     time         x         y         z       v_x       v_y       v_z  \
# 0    0.0  0.000000  0.000000  2.000000  1.000000  0.000000  0.000000
# 1    0.1  0.070065  0.070544  2.024845  0.989089  0.005108  0.496485
# 2    0.2  0.139344  0.140928  2.082419  0.987427  0.005099  0.654894
# 3    0.3  0.208902  0.211477  2.145020  0.994141  0.002398  0.597178
# 4    0.4  0.279177  0.282249  2.195860  0.999622  0.000575  0.419744
# 5    0.5  0.349836  0.353059  2.226609  1.000403  0.000241  0.195407
# 6    0.6  0.420506  0.423794  2.235143  0.999359  0.000386 -0.024529
# 7    0.7  0.491105  0.494482  2.223524  0.998998  0.000403 -0.207698
# 8    0.8  0.561704  0.565180  2.196261  0.999401  0.000285 -0.337465
# 9    0.9  0.632347  0.635898  2.158913  0.999839  0.000153 -0.409423
# 10   1.0  0.703032  0.706620  2.117047  1.000013  0.000050 -0.427877
# 11   1.1  0.773739  0.777333  2.075524  1.000039 -0.000021 -0.402606
# 12   1.2  0.844458  0.848039  2.038093  1.000067 -0.000066 -0.346073
